# %% [markdown]
# ************************* SELECT SEBSET FROM THE MAIN DATA FRAME ************************

# %%
import pandas as pd
data=pd.read_csv(r"C:\Users\PC\Desktop\train.csv") # r is use to roughly read the data
data
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
print("I’m interested in the order id of the train data")
Order_Id=data["Order ID"]
Order_Id.head() #it display first five data
# Out:
# I’m interested in the order id of the train data
# 0    CA-2017-152156
# 1    CA-2017-152156
# 2    CA-2017-138688
# 3    US-2016-108966
# 4    US-2016-108966
# Name: Order ID, dtype: object

# %%
print("I have a look at the shape of the output , it display the row and column")
shape1=data.shape
shape1
print("show the shape of city column")
shape2=data["City"].shape
shape2
# Out:
# I have a look at the shape of the output , it display the row and column
# show the shape of city column
# (9800,)

# %%
print("I’m interested in the ship mode and order date in train database.")
shipanddate=data[["Ship Mode","Order Date"]]
shipanddate
# Out:
# I’m interested in the ship mode and order date in train database.
#            Ship Mode  Order Date
# 0       Second Class  08/11/2017
# 1       Second Class  08/11/2017
# 2       Second Class  12/06/2017
# 3     Standard Class  11/10/2016
# 4     Standard Class  11/10/2016
# ...              ...         ...
# 9795  Standard Class  21/05/2017
# 9796  Standard Class  12/01/2016
# 9797  Standard Class  12/01/2016
# 9798  Standard Class  12/01/2016
# 9799  Standard Class  12/01/2016
#
# [9800 rows x 2 columns]

# %% [markdown]
# ******************** How do I filter specific rows from a DataFrame?**********************

# %%
print('i want to display record regarding a specific order date')
order_Date=data[data["Order Date"]=='08/11/2017']
order_Date
# Out:
# i want to display record regarding a specific order date
#    Row ID        Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017  Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City     State  Postal Code  \
# 0   Claire Gute  Consumer  United States  Henderson  Kentucky      42420.0
# 1   Claire Gute  Consumer  United States  Henderson  Kentucky      42420.0
#
#   Region       Product ID   Category Sub-Category  \
# 0  South  FUR-BO-10001798  Furniture    Bookcases
# 1  South  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales
# 0                  Bush Somerset Collection Bookcase  261.96
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94

# %%
print('i want to  display only those records whoes category is not furniture')
category=data[data['Category']!='Furniture'] 
category.head()
# Out:
# i want to  display only those records whoes category is not furniture
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 6       7  CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 7       8  CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 8       9  CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City       State  \
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 6  Brosina Hoffman   Consumer  United States      Los Angeles  California
# 7  Brosina Hoffman   Consumer  United States      Los Angeles  California
# ...

# %% [markdown]
# The condition inside the selection brackets train["category"]=='Furniture' checks for which rows the furniture values only tells true and false:

# %%
print('i want to  display only those records whoes category is not furniture and only display first five records')
category=data['Category']!='Furniture' 
category.head()
# Out:
# i want to  display only those records whoes category is not furniture
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# Name: Category, dtype: bool

# %% [markdown]
# look at the number of rows which satisfy the condition by checking the shape attribute of the resulting. it shows onlu the rows of whole database column

# %%
print(data.shape)
print(category.shape)
# Out:
# (9800, 18)
# (9800,)

# %%
print('I’m interested in the ship mode and custopmer id of the Train database and use with shape')
data1=data[['Ship Mode','Customer ID']]
print(data1)
print('display number of rows and column')
data2=data[['Ship Mode','Customer ID']].shape #To select multiple columns, use a list of column names within the selection brackets [].
data2
# Out:
# I’m interested in the ship mode and custopmer id of the Train database and use with shape
#            Ship Mode Customer ID
# 0       Second Class    CG-12520
# 1       Second Class    CG-12520
# 2       Second Class    DV-13045
# 3     Standard Class    SO-20335
# 4     Standard Class    SO-20335
# ...              ...         ...
# 9795  Standard Class    SH-19975
# 9796  Standard Class    CS-12490
# 9797  Standard Class    CS-12490
# 9798  Standard Class    CS-12490
# 9799  Standard Class    CS-12490
#
# [9800 rows x 2 columns]
# display number of rows and column
# (9800, 2)

# %%
print('The returned data type is a pandas DataFrame:')
df1=type(data[['Ship Mode','Customer ID']])
print(df1)
print('The selection returned a DataFrame with row and column')
df2=data[['Ship Mode','Customer ID']].shape
print(df2)
# Out:
# The returned data type is a pandas DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# The selection returned a DataFrame with row and column
# (9800, 2)

# %% [markdown]
# ********************    How do I filter specific rows from a DataFrame?  ************************

# %%
import pandas as pd
print('I’m interested in the region is west')
region=data['Region']=='West' #To select rows based on a conditional expression, use a condition inside the selection brackets [].
region.shape #hisplay number of columns
region.head(10) #display only first 10 records  and display true and false values
# Out:
# I’m interested in the region is west
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# Name: Region, dtype: bool
